# %%
import pandas as pd
import matplotlib.pyplot as plt

plt.style.use('seaborn')
plt.rcParams['figure.figsize'] = (16,9)

# %%
pwd
# Out:
# '/Users/kazim/Desktop/Project/Projects/traffic-optimization-with-RL'

# %%
path = '/Users/kazim/Desktop/Project/Projects/traffic-optimization-with-RL'

# %%
for i in range(3):
    df = (pd.read_csv('save/rewards{}.csv'.format(i))).drop(columns='Unnamed: 0')
    df.plot(figsize=(16,9))

# %%
path+'/model_output/traffic/DPG_10v10/statistics.csv'
# Out:
# '/Users/kazim/Desktop/Project/Projects/traffic-optimization-with-RL/model_output/traffic/DPG_10v10/statistics.csv'

# %%
stats = pd.read_csv(path+'/model_output/traffic/DPG_10v10/statistics.csv').set_index('episode')
stats.head()
# Out:
#          collision_0  collision_1  collision_2  collision_3  collision_4  \
# episode
# 1                300          298          299          294          300
# 2                300          300          300          300          300
# 3                300          300          300          300          300
# 4                300          300          300          300          300
# 5                300          300          300          300          300
#
#          collision_5  collision_6  collision_7  collision_8  collision_9  \
# episode
# 1                300          300          300          300          297
# 2                300          300          300          300          300
# 3                300          300          300          300          300
# 4                300          300          300          300          300
# 5                300          300          300          300          300
#
# ...

# %%
stats.iloc[:,:10].plot();
stats.iloc[:,10:20].plot();

# %%
stats.iloc[:,20:30].plot();
stats.iloc[:,30:40].plot();

# %%
stats.iloc[:,40:50].plot();
stats.iloc[:,50:60].plot();
