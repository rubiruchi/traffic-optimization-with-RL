# %% [markdown]
# # Data Analysis

# %%
import pandas as pd
import matplotlib.pyplot as plt

plt.style.use('seaborn')
plt.rcParams['figure.figsize'] = (16,9)

# %%
pwd
# Out:
# '/Users/kazim/Desktop/Project/Projects/traffic-optimization-with-RL'

# %%
path = '/Users/kazim/Desktop/Project/Projects/traffic-optimization-with-RL'

# %%
# for i in range(3):
#     df = (pd.read_csv('save/rewards{}.csv'.format(i))).drop(columns='Unnamed: 0')
#     df.plot(figsize=(16,9))

# %%
path+'/model_output/traffic/DPG_5v5/statistics.csv'
# Out:
# '/Users/kazim/Desktop/Project/Projects/traffic-optimization-with-RL/model_output/traffic/DPG_5v5/statistics.csv'

# %%
stats = pd.read_csv(path+'/model_output/traffic/DPG_5v5/statistics.csv').set_index('episode')
stats.head()
# Out:
#          collision_0  collision_1  collision_2  collision_3  collision_4  \
# episode
# 1                117           29           44           33           58
# 2                105           46           58           30           72
# 3                119           50           65           58           85
# 4                 95           72           22           42           75
# 5                107           29           42           32           54
#
#          collision_5  collision_6  collision_7  collision_8  collision_9  \
# episode
# 1                 63           47           39          124           78
# 2                 38           28           47          130           80
# 3                 88           19           49          119           71
# 4                 30           13           76           77           69
# 5                 57           34           65           84           64
#
#            ...       loss_0    loss_1    loss_2    loss_3    loss_4    loss_5  \
# episode    ...
# 1          ...     0.068975  0.003742 -0.019607 -0.026000  0.038253  0.043023
# 2          ...     0.079401  0.011568  0.013857 -0.002256  0.028219  0.009923
# 3          ...     0.099604  0.018409 -0.010060  0.029845  0.001398  0.032588
# 4          ...     0.062905  0.002473 -0.009307  0.040031 -0.009823  0.022504
# 5          ...     0.088201 -0.004160 -0.038912  0.003882  0.033277  0.033877
#
#            loss_6    loss_7    loss_8    loss_9
# episode
# 1       -0.000153 -0.007999  0.079177  0.010924
# 2       -0.008164 -0.008494  0.074092  0.027706
# 3        0.000657 -0.027121  0.031652  0.006492
# 4       -0.011667 -0.012519  0.024121  0.011447
# 5        0.002246 -0.003970 -0.016744  0.003396
#
# [5 rows x 30 columns]

# %%
#collision for agent0
stats.iloc[::20,:10].sum(axis=1).plot(alpha=0.5);
plt.ylabel('collision');
plt.title('Total collision in an episode');

# %%
#reward for agent0
stats.iloc[::20,10:20].sum(axis=1).plot(alpha=0.5);
plt.ylabel('reward');
plt.title('Total reward in an episode');

# %%
#loss for agent0
stats.iloc[::20,20:30].mean(axis=1).plot(alpha=0.5);
plt.ylabel('loss');
plt.title('Mean loss (DPG) in an episode');
